# %%
# %%time

import pandas as pd
from sklearn.cluster import KMeans
from patternly.detection import AnomalyDetection

data_file = "./data/example0.dat"

# Define clustering algorithm to be used for clustering distance matrix
n_clusters_ = 2
kmeans = KMeans(n_clusters=n_clusters_)

# Fit detection pipeline to training data
pipeline = AnomalyDetection(anomaly_sensitivity=4, clustering_alg=kmeans, quantize=False, eps=0.1, verbose=True)
pipeline = pipeline.fit(data_file)
# Out:
# Calculating distance matrix...
# Clustering distance matrix...
# Writing cluster 1/2 to file...
# Writing cluster 2/2 to file...
# Generating cluster PFSA 1/2...
# Generating cluster PFSA 2/2...
# Calculating cluster PFSA means and stds...
# CPU times: user 12min 1s, sys: 21.5 s, total: 12min 23s
# Wall time: 9min 22s

# %%
# %%time

predictions = pd.DataFrame(pipeline.predict())
anomalies = predictions[predictions[0] == True]
print(anomalies.shape)
anomalies
# Out:
# (23, 1)
# CPU times: user 1min 12s, sys: 1.11 s, total: 1min 13s
# Wall time: 1min 13s
#          0
# 2000  True
# 2001  True
# 2002  True
# 2003  True
# 2004  True
# 2005  True
# 2006  True
# 2007  True
# 2008  True
# 2009  True
# 2010  True
# 2011  True
# 2012  True
# 2013  True
# 2014  True
# 2015  True
# 2016  True
# 2017  True
# 2018  True
# 2019  True
# 2020  True
# 2021  True
# 2022  True
